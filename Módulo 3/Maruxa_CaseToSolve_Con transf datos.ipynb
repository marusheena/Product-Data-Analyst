# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
import pandas as pd

car_evaluation = '/Users/fermarinsanchez/dev/MaruPython/MODULO 3/Case to solve/car_evaluation.csv'
car_data = pd.read_csv(car_evaluation)

#primeras 5 filas
print(car_data.head())
print("-"*50)
#últimas 5 filas
print(car_data.tail())
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc
# --------------------------------------------------
#      vhigh vhigh.1      2   2.1 small   low  unacc
# 1722   low     low  5more  more   med   med   good
# 1723   low     low  5more  more   med  high  vgood
# 1724   low     low  5more  more   big   low  unacc
# 1725   low     low  5more  more   big   med   good
# 1726   low     low  5more  more   big  high  vgood

# %%
#Dimensiones del dataframe
print(f"El dataset tiene {car_data.shape[0]} filas y {car_data.shape[1]} columnas")
# Out:
# El dataset tiene 1727 filas y 7 columnas

# %%
#Tipo de datos de las columnas
print("TIPOS DE DATOS:")
print()
print(car_data.dtypes)
print("-"*50)
#Información del dataframe
print("INFORMACIÓN DEL DATA FRAME:")
print()
print(car_data.info())
# Out:
# TIPOS DE DATOS:
#
# vhigh      object
# vhigh.1    object
# 2          object
# 2.1        object
# small      object
# low        object
# unacc      object
# dtype: object
# --------------------------------------------------
# INFORMACIÓN DEL DATA FRAME:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   vhigh    1727 non-null   object
#  1   vhigh.1  1727 non-null   object
#  2   2        1727 non-null   object
#  3   2.1      1727 non-null   object
#  4   small    1727 non-null   object
#  5   low      1727 non-null   object
#  6   unacc    1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB
# None

# %%
car_data.count()
# Out:
# vhigh      1727
# vhigh.1    1727
# 2          1727
# 2.1        1727
# small      1727
# low        1727
# unacc      1727
# dtype: int64

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#ESTADÍSTICA DESCRIPTIVA
car_data.describe()
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %% [markdown]
# RENOMBRAR LAS COLUMNAS

# %%
# Renombrar las columnas
car_data.columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

print("\nNew column names:")
print(car_data.columns)
# Out:
# New column names:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class'], dtype='object')

# %%
print(car_data.head())
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %% [markdown]
# DATA WRANGLING

# %%
#VALORES DUPLICADOS
car_data.duplicated().sum()
# Out:
# 0

# %%
#VALORES DUPLICADOS
car_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1722    False
# 1723    False
# 1724    False
# 1725    False
# 1726    False
# Length: 1727, dtype: bool

# %%
#VALORES UNICOS
car_data.nunique()
# Out:
# buying      4
# maint       4
# doors       4
# persons     3
# lug_boot    3
# safety      3
# class       4
# dtype: int64

# %%
# Imprimir los valores únicos de cada columna 
for column in car_data.columns:
    unique_values = car_data[column].unique()
    print(f"Valores únicos en la columna '{column}': {unique_values}")
# Out:
# Valores únicos en la columna 'buying': ['vhigh' 'high' 'med' 'low']
# Valores únicos en la columna 'maint': ['vhigh' 'high' 'med' 'low']
# Valores únicos en la columna 'doors': ['2' '3' '4' '5more']
# Valores únicos en la columna 'persons': ['2' '4' 'more']
# Valores únicos en la columna 'lug_boot': ['small' 'med' 'big']
# Valores únicos en la columna 'safety': ['med' 'high' 'low']
# Valores únicos en la columna 'class': ['unacc' 'acc' 'vgood' 'good']

# %%
#Comprobamos los valores nulos
car_data.isnull().sum()

#Comprobamos los valores nulos por columna
car_data.isnull().sum()/len(car_data)*100

#Comprobamos los valores nulos por columna
car_data.isnull().sum()/len(car_data)*100
# Out:
# buying      0.0
# maint       0.0
# doors       0.0
# persons     0.0
# lug_boot    0.0
# safety      0.0
# class       0.0
# dtype: float64

# %%
print(car_data.head())
print(car_data['buying'].value_counts())
print(car_data['maint'].value_counts())
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64

# %% [markdown]
# # CONCLUSIONES:
# - El DataFrame es del tipo pandas.core.frame.DataFrame, es decir, es una estructura de datos utilizada por pandas.
# - Tiene 1727 entradas con índices que van de o a 1726.
# - Tiene un total de 7 columnas, todas son del tipo "object".
# - No existen valores nulos con lo que no es necesario hacer limpieza de NaN.
# - Dado que todas las columnas son de tipo 'object', si se requiere realizar operaciones numéricas o de modelado, puede ser necesario convertir estos datos a tipos numéricos o categóricos apropiados.
# - No existen valores duplicados en el conjunto de datos.
# - Cada columna tiene un número determinado de valores definidos que representan diferentes niveles (p.e. Valores únicos en la columna 'buying': ['vhigh' 'high' 'med' 'low'])

# %%
# Convertir '5more' y 'more' a 5
car_data['doors'] = car_data['doors'].replace('5more', 5).astype(int)
car_data['persons'] = car_data['persons'].replace('more', 5).astype(int)

# %%
# Aplicar One-Hot Encoding a 'lug_boot' y 'safety'
car_data = pd.get_dummies(car_data, columns=['lug_boot', 'safety'])

# Convertir las nuevas columnas booleanas a enteros
bool_columns = [col for col in car_data.columns if 'lug_boot' in col or 'safety' in col]
car_data[bool_columns] = car_data[bool_columns].astype(int)

# %%
print(car_data.dtypes)
# Out:
# buying            object
# maint             object
# doors              int64
# persons            int64
# class             object
# lug_boot_big       int64
# lug_boot_med       int64
# lug_boot_small     int64
# safety_high        int64
# safety_low         int64
# safety_med         int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear un DataFrame para facilitar la visualización
safety_data = car_data[['safety_high', 'safety_low', 'safety_med']]
safety_counts = safety_data.sum().sort_values()

# Gráfico de barras
plt.figure(figsize=(8, 6))
sns.barplot(x=safety_counts.index, y=safety_counts.values)
plt.title('Distribución de las Puntuaciones de Seguridad', fontweight='bold', fontsize=20)
plt.xlabel('Categoría de Seguridad')
plt.ylabel('Cantidad de Automóviles')
plt.show()

# %% [markdown]
# *Conclusión:*
# La gráfica indica que la distribución de los valores de seguridad de los vehículos es uniforme.

# %%
import matplotlib.pyplot as plt

# Contar las frecuencias de cada evaluación
class_counts = car_data['class'].value_counts(normalize=True) * 100

# Crear el gráfico circular
plt.figure(figsize=(8, 6))
plt.pie(class_counts, labels=labels_upper, autopct='%1.1f%%', startangle=140, colors=['#E6E6FA', '#ADD8E6', 'orange', 'red'])
plt.title('Proporción de Evaluaciones de Vehículos', fontweight='bold', fontsize=20)
labels_upper = [label.upper() for label in class_counts.index]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 8
#       6 # Crear el gráfico circular
#       7 plt.figure(figsize=(8, 6))
# ----> 8 plt.pie(class_counts, labels=labels_upper, autopct='%1.1f%%', startangle=140, colors=['#E6E6FA', '#ADD8E6', 'orange', 'red'])
#       9 plt.title('Proporción de Evaluaciones de Vehículos', fontweight='bold', fontsize=20)
#      10 labels_upper = [label.upper() for label in class_counts.index]
#
# NameError: name 'labels_upper' is not defined

# %% [markdown]
# *Conclusión:*
# Hay un gran número de vehículos en la categoría de "inaceptables" lo que proporciona un elevado margen de mejora dentro de la calidad de los vehículos y la satisfacción del cliente.

# %%
import matplotlib.pyplot as plt
import pandas as pd

pivot_data = car_data.pivot_table(index='class', columns='buying', aggfunc='size', fill_value=0)

colors = ['#FF9999', '#66B3FF', '#99FF99', '#E6E6FA']  # Rojo claro, Azul claro, Verde claro, Naranja claro

ax = pivot_data.plot(kind='bar', color=colors, figsize=(10, 7))
plt.title('Evaluación del Vehículo por Precio de Compra', fontsize=24, fontweight='bold')
plt.xlabel('Evaluación', fontsize=18)
plt.ylabel('Cantidad', fontsize=18)
plt.xticks(rotation=0)  # Mantener las etiquetas del eje X horizontales
plt.legend(title='Precio de Compra', title_fontsize='13', fontsize='11')

for p in ax.patches: 
    ax.annotate(f'{int(p.get_height())}',  
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center',  
                xytext=(0, 9),
                textcoords='offset points', fontsize=10, color='black')

plt.show()

# %% [markdown]
# *Conclusión:*
# Los vehículos más económicos tienen una evaluación más alta contrariamente a la idea de "más caro, mejor"; la relación calidad-precio es mejor.
# Predominan los vehículos de la categoría "inaceptables", es decir, que no cumplen con estándares deseables, idependientemente del precio.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Asumiendo que 'car_data' es tu DataFrame y que contiene una columna 'class'
# Crear un countplot para la columna 'class'
sns.countplot(x='class', data=car_data, palette='deep')

# Añadir título y etiquetas para los ejes
plt.title('Distribución de Evaluaciones de Vehículos')
plt.xlabel('Evaluación')
plt.ylabel('Cantidad')

plt.show()
# Out:
# /var/folders/yc/76rsrjl17hqc0qjmpxyqlbgc0000gn/T/ipykernel_3438/3497889212.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', data=car_data, palette='deep')

# %% [markdown]
# *Conclusión:*
# De nuevo volvemos a ver que hay una gran de vehículos de categoría inaceptable lo que ofrece un amplio margen de mejora de los vehículos.

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport

profile = ProfileReport(car_data, title="Car Evaluation Dataset Profiling Report")
profile.to_file("car_evaluation_profile_report.html")
profile.to_notebook_iframe()
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-04 17:34:53.114478&quot;&gt;&lt;title&gt;Car Evaluation Dataset Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
